# %%
import braille
import cv2

# %% [markdown]
# # TEST 1

# %%
image = cv2.imread('images/tests/2.png', 0)
text = braille.decode(image, dot_size=30, debug=True)
print('Decoded text: %s' % text)
# Out:
# Decoded text: Happy new year 2020!

# %% [markdown]
# # TEST 2

# %%
image = cv2.imread('images/tests/3.png', 0)
text = braille.decode(image, 45, debug=True)
print('Decoded text: %s' % text)
# Out:
# Decoded text: It has been said that Poland is dead, exhausted, enslaved, but here is the proof of her life and triumph-Henryk Sienkiewicz

# %% [markdown]
# # TEST 3

# %%
image = cv2.imread('images/tests/4.png', 0)
text = braille.decode(image, 50, debug=True)
print('Decoded text: %s' % text)
# Out:
# Decoded text: Somewhere out there the world must have an end - Wislawa Szymborska

# %% [markdown]
# # TEST 4

# %%
image = cv2.imread('images/tests/5.png', 0)
text = braille.decode(image, 60, debug=True)
print('Decoded text: %s' % text)
# Out:
# Decoded text: It's most beautiful when You don't feel beautiful at all And when you simply exist Like everythingelse in the world

# %% [markdown]
# # TEST 5

# %%
image = cv2.imread('images/tests/6.png', 0)
text = braille.decode(image, 65, debug=True)
print('Decoded text: %s' % text)
# Out:
# Decoded text: To be, or not to be, that is the question.

# %% [markdown]
# # TEST 6

# %%
image = cv2.imread('images/tests/7.png', 0)
text = braille.decode(image, 33, debug=True)
print('Decoded text: %s' % text)
# Out:
# Decoded text: Beauty is a promise, a vision of happiness. It is not yet happiness it has an element of sadnessthat comes from it being just an endowment.

# %% [markdown]
# # TEST 7

# %%
image = cv2.imread('images/tests/8.png', 0)
text = braille.decode(image, 40, debug=True)
print('Decoded text: %s' % text)
# Out:
# Decoded text: Where do consequences lead Depends on the escort. Stanislaw Lem

# %% [markdown]
# # TEST 8

# %%
image = cv2.imread('images/tests/1.png', 0)
text = braille.decode(image, 30, debug=True)
print('Decoded text: %s' % text)
# Out:
# Decoded text: I think the brain is essentially a computer and consciousness is like a computer program. It will cease to run when the computer is turned off. Theoretically, it could be re-created on a neural network, but that would be very difficult,as it would require all one' memories. Stephen Hawking
